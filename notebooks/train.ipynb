# %%
# This pre-amble sets up auto-reloading of any on-disk modules we are hacking on.
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
# This pre-amble makes mlx_esm visible to this notebook.
import os
import sys
module_path = os.path.abspath(os.path.join(".."))
sys.path.insert(0, module_path)

# %%
# This pre-amble makes matplotlib available in this notebook.
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from mlx_esm.train import Trainer

t = Trainer()
t.load()
t.train()
# Out:
# 📥 loading data
# 🚂 training:   0%|          | 0/100000 [00:00<?, ?it/s, loss=NaN]

# %%
t.plot_loss("train", start_idx=100)
